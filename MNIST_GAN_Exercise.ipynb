# %% [markdown]
# # Generative Adversarial Network
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the MNIST dataset. From this, we'll be able to generate new handwritten digits!
#
# GANs were [first reported on](https://arxiv.org/abs/1406.2661) in 2014 from Ian Goodfellow and others in Yoshua Bengio's lab. Since then, GANs have exploded in popularity. Here are a few examples to check out:
#
# * [Pix2Pix](https://affinelayer.com/pixsrv/)
# * [CycleGAN & Pix2Pix in PyTorch, Jun-Yan Zhu](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix)
# * [A list of generative models](https://github.com/wiseodd/generative-models)
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes "fake" data to pass to the discriminator. The discriminator also sees real training data and predicts if the data it's received is real or fake.
# > * The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real, training data.
# * The discriminator is a classifier that is trained to figure out which data is real and which is fake.
#
# What ends up happening is that the generator learns to make data that is indistinguishable from real data to the discriminator.
#
# <img src='assets/gan_pipeline.png' width=70% />
#
# The general structure of a GAN is shown in the diagram above, using MNIST images as data. The latent sample is a random vector that the generator uses to construct its fake images. This is often called a **latent vector** and that vector space is called **latent space**. As the generator trains, it figures out how to map latent vectors to recognizable images that can fool the discriminator.
#
# If you're interested in generating only new images, you can throw out the discriminator after training. In this notebook, I'll show you how to define and train these adversarial networks in PyTorch and generate new images!

# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)

# %% [markdown]
# ### Visualize the data

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[np.random.randint(0,len(images))])

fig = plt.figure(figsize = (3,3)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.

# %% [markdown]
# ## Discriminator
#
# The discriminator network is going to be a pretty typical linear classifier. To make this network a universal function approximator, we'll need at least one hidden layer, and these hidden layers should have one key attribute:
# > All hidden layers will have a [Leaky ReLu](https://pytorch.org/docs/stable/nn.html#torch.nn.LeakyReLU) activation function applied to their outputs.
#
# <img src='assets/gan_network.png' width=70% />
#
# #### Leaky ReLu
#
# We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# <img src='assets/leaky_relu.png' width=40% />
#
# #### Sigmoid Output
#
# We'll also take the approach of using a more numerically stable loss function on the outputs. Recall that we want the discriminator to output a value 0-1 indicating whether an image is _real or fake_.
# > We will ultimately use [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss), which combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# So, our final output layer should not have any activation function applied to it.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        self.input_size = input_size
        
        # define all layers
        self.hidden1 = nn.Linear(input_size,   hidden_dim*4)
        self.hidden2 = nn.Linear(hidden_dim*4, hidden_dim*2)
        self.hidden3 = nn.Linear(hidden_dim*2, hidden_dim)
        self.out     = nn.Linear(hidden_dim,   output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, self.input_size)
        
        # pass x through all layers
        # apply leaky relu activation to all hidden layers
        x = F.leaky_relu(self.hidden1(x), negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.hidden2(x), negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.hidden3(x), negative_slope=0.2)
        x = self.dropout(x)
        x = self.out(x)

        return x

# %% [markdown]
# ## Generator
#
# The generator network will be almost exactly the same as the discriminator network, except that we're applying a [tanh activation function](https://pytorch.org/docs/stable/nn.html#tanh) to our output layer.
#
# #### tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output, which scales the output to be between -1 and 1, instead of 0 and 1.
#
# <img src='assets/tanh_fn.png' width=40% />
#
# Recall that we also want these outputs to be comparable to the *real* input pixel values, which are read in as normalized values between 0 and 1.
# > So, we'll also have to **scale our real input images to have pixel values between -1 and 1** when we train the discriminator.
#
# I'll do this in the training loop, later on.

# %%
class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        self.input_size = input_size
        
        # define all layers
        # define all layers
        self.hidden1 = nn.Linear(input_size,   hidden_dim)
        self.hidden2 = nn.Linear(hidden_dim,   hidden_dim*2)
        self.hidden3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        self.out     = nn.Linear(hidden_dim*4, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
        # pass x through all layers
        #x = x.view(-1, self.input_size)  ########## maybe not needed?
        
        # final layer should have tanh applied
        x = F.leaky_relu(self.hidden1(x), negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.hidden2(x), negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.hidden3(x), negative_slope=0.2)
        x = self.dropout(x)
        x = F.tanh(self.out(x))
        
        return x

# %% [markdown]
# ## Model hyperparameters

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 28 * 28
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of *last* hidden layer in the discriminator
d_hidden_size = 32 #512//4

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of discriminator output (generated image)
g_output_size = 28 * 28
# Size of *first* hidden layer in the generator
g_hidden_size = 32 #512//4

# %% [markdown]
# ## Build complete network
#
# Now we're instantiating the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
# instantiate discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator(
#   (hidden1): Linear(in_features=784, out_features=128, bias=True)
#   (hidden2): Linear(in_features=128, out_features=64, bias=True)
#   (hidden3): Linear(in_features=64, out_features=32, bias=True)
#   (out): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3)
# )
#
# Generator(
#   (hidden1): Linear(in_features=100, out_features=32, bias=True)
#   (hidden2): Linear(in_features=32, out_features=64, bias=True)
#   (hidden3): Linear(in_features=64, out_features=128, bias=True)
#   (out): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# <img src='assets/gan_pipeline.png' width=70% />
#
# The losses will by binary cross entropy loss with logits, which we can get with [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss). This combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# For the real images, we want `D(real_images) = 1`. That is, we want the discriminator to classify the the real images with a label = 1, indicating that these are real. To help the discriminator generalize better, the labels are **reduced a bit from 1.0 to 0.9**. For this, we'll use the parameter `smooth`; if True, then we should smooth our labels. In PyTorch, this looks like `labels = torch.ones(size) * 0.9`
#
# The discriminator loss for the fake data is similar. We want `D(fake_images) = 0`, where the fake images are the _generator output_, `fake_images = G(z)`.
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get `D(fake_images) = 1`. In this case, the labels are **flipped** to represent that the generator is trying to fool the discriminator into thinking that the images it generates (fakes) are real!

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
    # compare logits to real labels
    # smooth labels if smooth=True
    criterion = nn.BCEWithLogitsLoss()
    batch_size = D_out.size(0)
    target = torch.ones(batch_size)
    if smooth:
        target = torch.ones(batch_size) * 0.9
        
#     print("D_out.shape:  {}".format(D_out.shape))
#     print("D_out.squeeze().shape:  {}".format(D_out.squeeze().shape))
#     print("target.shape: {}".format(target.shape))
    loss = criterion(D_out.squeeze(), target)
    return loss

def fake_loss(D_out):
    # compare logits to fake labels
    criterion = nn.BCEWithLogitsLoss()
    batch_size = D_out.size(0)
    target = torch.zeros(batch_size)
    loss = criterion(D_out.squeeze(), target)
    return loss

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So, we'll define two separate Adam optimizers.

# %%
import torch.optim as optim

# learning rate for optimizers
lr = 0.002

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr=lr)
g_optimizer = optim.Adam(G.parameters(), lr=lr)

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. We'll use our functions `real_loss` and `fake_loss` to help us calculate the discriminator losses in all of the following cases.
#
# ### Discriminator training
# 1. Compute the discriminator loss on real, training images
# 2. Generate fake images
# 3. Compute the discriminator loss on fake, generated images
# 4. Add up real and fake loss
# 5. Perform backpropagation + an optimization step to update the discriminator's weights
#
# ### Generator training
# 1. Generate fake images
# 2. Compute the discriminator loss on fake images, using **flipped** labels!
# 3. Perform backpropagation + an optimization step to update the generator's weights
#
# #### Saving Samples
#
# As we train, we'll also print out some loss statistics and save some generated "fake" samples.

# %%
import pickle as pkl

# training hyperparams
num_epochs = 100

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 400

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        ## Important rescaling step ## 
        real_images = real_images*2 - 1  # rescale input images from [0,1) to [-1, 1)
        
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
        d_optimizer.zero_grad()   
        
        # 1. Train with real images
        D_out_real = D(real_images)
        
        # Compute the discriminator losses on real images
        # use smoothed labels
        D_loss_real = real_loss(D_out_real,smooth=True)
        
        # 2. Train with fake images
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images    
        D_out_fake = D(fake_images)
        D_loss_fake = fake_loss(D_out_fake)
        
        # add up real and fake losses and perform backprop
        d_loss = D_loss_real + D_loss_fake #NAS - I think this is right?
        #print(f"d_loss: {d_loss}")
        d_loss.backward()
        d_optimizer.step()
        
        # =========================================
        #            TRAIN THE GENERATOR
        # =========================================
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images 
        # using flipped labels!
        D_output_fake = D(fake_images)
        g_loss = real_loss(D_output_fake)  # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()
        
        #######################################
        
        # Print some loss stats
        if batch_i % print_every == 0:
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    ## AFTER EACH EPOCH##
    # append discriminator loss and generator loss
    losses.append((d_loss.item(), g_loss.item()))
    
    # generate and save sample, fake images
    G.eval() # eval mode for generating samples
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # back to train mode


# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# /home/nathan/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  100] | d_loss: 1.4125 | g_loss: 0.6577
# Epoch [    1/  100] | d_loss: 1.1194 | g_loss: 1.4909
# Epoch [    1/  100] | d_loss: 1.5727 | g_loss: 0.5751
# Epoch [    2/  100] | d_loss: 1.0561 | g_loss: 1.7343
# Epoch [    2/  100] | d_loss: 0.9227 | g_loss: 3.5480
# Epoch [    2/  100] | d_loss: 1.1178 | g_loss: 1.5276
# Epoch [    3/  100] | d_loss: 1.2969 | g_loss: 1.0398
# Epoch [    3/  100] | d_loss: 1.0847 | g_loss: 1.0225
# Epoch [    3/  100] | d_loss: 1.2478 | g_loss: 0.9476
# Epoch [    4/  100] | d_loss: 1.1765 | g_loss: 1.2829
# Epoch [    4/  100] | d_loss: 1.1642 | g_loss: 1.0117
# Epoch [    4/  100] | d_loss: 0.9292 | g_loss: 1.2959
# Epoch [    5/  100] | d_loss: 1.1775 | g_loss: 1.3309
# Epoch [    5/  100] | d_loss: 1.0707 | g_loss: 1.1113
# Epoch [    5/  100] | d_loss: 0.9979 | g_loss: 1.6851
# Epoch [    6/  100] | d_loss: 1.2027 | g_loss: 1.0377
# Epoch [    6/  100] | d_loss: 0.9889 | g_loss: 1.6590
# Epoch [    6/  100] | d_loss: 1.1602 | g_loss: 1.1325
# Epoch [    7/  100] | d_loss: 1.0406 | g_loss: 2.0085
# Epoch [    7/  100] | d_loss: 1.1578 | g_loss: 1.5930
# Epoch [    7/  100] | d_loss: 1.2142 | g_loss: 1.2015
# Epoch [    8/  100] | d_loss: 1.2722 | g_loss: 1.1249
# Epoch [    8/  100] | d_loss: 1.0010 | g_loss: 1.6714
# Epoch [    8/  100] | d_loss: 1.0918 | g_loss: 1.8540
# Epoch [    9/  100] | d_loss: 1.3035 | g_loss: 1.7578
# Epoch [    9/  100] | d_loss: 1.2613 | g_loss: 1.1930
# Epoch [    9/  100] | d_loss: 1.2972 | g_loss: 1.0863
# Epoch [   10/  100] | d_loss: 1.2073 | g_loss: 1.1319
# Epoch [   10/  100] | d_loss: 1.2349 | g_loss: 0.9063
# Epoch [   10/  100] | d_loss: 1.3482 | g_loss: 0.9422
# Epoch [   11/  100] | d_loss: 1.2885 | g_loss: 0.9221
# Epoch [   11/  100] | d_loss: 1.1658 | g_loss: 1.2224
# Epoch [   11/  100] | d_loss: 1.1546 | g_loss: 1.5946
# Epoch [   12/  100] | d_loss: 1.2514 | g_loss: 1.1658
# Epoch [   12/  100] | d_loss: 1.2827 | g_loss: 0.9276
# Epoch [   12/  100] | d_loss: 1.2817 | g_loss: 1.0803
# Epoch [   13/  100] | d_loss: 1.2183 | g_loss: 0.9827
# Epoch [   13/  100] | d_loss: 1.2616 | g_loss: 1.1819
# Epoch [   13/  100] | d_loss: 1.3105 | g_loss: 0.8083
# Epoch [   14/  100] | d_loss: 1.2183 | g_loss: 1.3110
# Epoch [   14/  100] | d_loss: 1.3207 | g_loss: 1.1026
# Epoch [   14/  100] | d_loss: 1.3374 | g_loss: 1.0475
# Epoch [   15/  100] | d_loss: 1.3523 | g_loss: 1.1347
# Epoch [   15/  100] | d_loss: 1.3076 | g_loss: 0.9129
# Epoch [   15/  100] | d_loss: 1.3220 | g_loss: 0.9376
# Epoch [   16/  100] | d_loss: 1.3567 | g_loss: 0.9691
# Epoch [   16/  100] | d_loss: 1.2678 | g_loss: 1.0095
# Epoch [   16/  100] | d_loss: 1.2382 | g_loss: 1.1145
# Epoch [   17/  100] | d_loss: 1.2341 | g_loss: 1.0023
# Epoch [   17/  100] | d_loss: 1.2940 | g_loss: 0.9962
# Epoch [   17/  100] | d_loss: 1.3079 | g_loss: 1.0573
# Epoch [   18/  100] | d_loss: 1.2332 | g_loss: 0.9518
# Epoch [   18/  100] | d_loss: 1.2531 | g_loss: 0.9324
# Epoch [   18/  100] | d_loss: 1.2146 | g_loss: 1.1505
# Epoch [   19/  100] | d_loss: 1.3178 | g_loss: 1.0313
# Epoch [   19/  100] | d_loss: 1.2339 | g_loss: 1.2067
# Epoch [   19/  100] | d_loss: 1.1792 | g_loss: 1.1602
# Epoch [   20/  100] | d_loss: 1.0536 | g_loss: 1.2803
# Epoch [   20/  100] | d_loss: 1.2140 | g_loss: 1.6241
# Epoch [   20/  100] | d_loss: 1.1993 | g_loss: 1.1963
# Epoch [   21/  100] | d_loss: 1.1884 | g_loss: 0.9786
# Epoch [   21/  100] | d_loss: 1.2696 | g_loss: 1.0575
# Epoch [   21/  100] | d_loss: 1.3881 | g_loss: 0.9662
# Epoch [   22/  100] | d_loss: 1.3142 | g_loss: 1.6311
# Epoch [   22/  100] | d_loss: 1.2115 | g_loss: 1.2580
# Epoch [   22/  100] | d_loss: 1.2461 | g_loss: 0.9867
# Epoch [   23/  100] | d_loss: 1.2574 | g_loss: 1.2030
# Epoch [   23/  100] | d_loss: 1.2390 | g_loss: 1.0176
# Epoch [   23/  100] | d_loss: 1.2543 | g_loss: 0.9850
# Epoch [   24/  100] | d_loss: 1.2633 | g_loss: 1.1320
# Epoch [   24/  100] | d_loss: 1.3013 | g_loss: 1.0057
# Epoch [   24/  100] | d_loss: 1.2043 | g_loss: 0.9382
# Epoch [   25/  100] | d_loss: 1.3585 | g_loss: 0.7720
# Epoch [   25/  100] | d_loss: 1.3027 | g_loss: 1.0265
# Epoch [   25/  100] | d_loss: 1.2534 | g_loss: 1.1926
# Epoch [   26/  100] | d_loss: 1.1864 | g_loss: 1.1129
# Epoch [   26/  100] | d_loss: 1.3331 | g_loss: 0.8943
# Epoch [   26/  100] | d_loss: 1.2222 | g_loss: 1.7297
# Epoch [   27/  100] | d_loss: 1.2339 | g_loss: 1.1265
# Epoch [   27/  100] | d_loss: 1.2205 | g_loss: 1.3711
# Epoch [   27/  100] | d_loss: 1.3269 | g_loss: 1.0213
# Epoch [   28/  100] | d_loss: 1.3234 | g_loss: 0.8943
# Epoch [   28/  100] | d_loss: 1.2638 | g_loss: 1.0279
# Epoch [   28/  100] | d_loss: 1.2620 | g_loss: 1.2006
# Epoch [   29/  100] | d_loss: 1.2582 | g_loss: 1.3885
# Epoch [   29/  100] | d_loss: 1.2100 | g_loss: 0.8363
# Epoch [   29/  100] | d_loss: 1.2636 | g_loss: 0.8487
# Epoch [   30/  100] | d_loss: 1.4589 | g_loss: 1.3689
# Epoch [   30/  100] | d_loss: 1.2955 | g_loss: 0.8322
# Epoch [   30/  100] | d_loss: 1.4952 | g_loss: 0.9201
# Epoch [   31/  100] | d_loss: 1.1757 | g_loss: 1.9433
# Epoch [   31/  100] | d_loss: 1.3085 | g_loss: 1.1692
# Epoch [   31/  100] | d_loss: 1.3802 | g_loss: 0.9213
# Epoch [   32/  100] | d_loss: 1.3773 | g_loss: 1.0262
# Epoch [   32/  100] | d_loss: 1.3206 | g_loss: 1.1182
# Epoch [   32/  100] | d_loss: 1.3367 | g_loss: 1.1639
# Epoch [   33/  100] | d_loss: 1.2651 | g_loss: 1.1134
# Epoch [   33/  100] | d_loss: 1.2611 | g_loss: 1.2239
# Epoch [   33/  100] | d_loss: 1.2963 | g_loss: 1.0053
# Epoch [   34/  100] | d_loss: 1.3176 | g_loss: 0.9402
# Epoch [   34/  100] | d_loss: 1.1601 | g_loss: 1.0896
# Epoch [   34/  100] | d_loss: 1.3924 | g_loss: 0.8645
# Epoch [   35/  100] | d_loss: 1.3333 | g_loss: 0.8976
# Epoch [   35/  100] | d_loss: 1.2787 | g_loss: 0.9724
# Epoch [   35/  100] | d_loss: 1.2998 | g_loss: 0.9467
# Epoch [   36/  100] | d_loss: 1.3028 | g_loss: 1.3717
# Epoch [   36/  100] | d_loss: 1.3083 | g_loss: 1.1120
# Epoch [   36/  100] | d_loss: 1.3038 | g_loss: 0.8530
# Epoch [   37/  100] | d_loss: 1.3326 | g_loss: 0.9290
# Epoch [   37/  100] | d_loss: 1.1897 | g_loss: 0.8644
# Epoch [   37/  100] | d_loss: 1.2885 | g_loss: 1.0072
# Epoch [   38/  100] | d_loss: 1.3565 | g_loss: 0.8275
# Epoch [   38/  100] | d_loss: 1.3071 | g_loss: 0.9577
# Epoch [   38/  100] | d_loss: 1.3143 | g_loss: 1.2065
# Epoch [   39/  100] | d_loss: 1.2511 | g_loss: 1.1180
# Epoch [   39/  100] | d_loss: 1.3173 | g_loss: 0.9721
# Epoch [   39/  100] | d_loss: 1.3084 | g_loss: 0.9105
# Epoch [   40/  100] | d_loss: 1.3570 | g_loss: 1.0788
# Epoch [   40/  100] | d_loss: 1.2880 | g_loss: 0.9734
# Epoch [   40/  100] | d_loss: 1.3843 | g_loss: 0.9078
# Epoch [   41/  100] | d_loss: 1.3004 | g_loss: 1.1227
# Epoch [   41/  100] | d_loss: 1.2875 | g_loss: 0.8942
# Epoch [   41/  100] | d_loss: 1.3735 | g_loss: 0.8983
# Epoch [   42/  100] | d_loss: 1.3556 | g_loss: 0.9304
# Epoch [   42/  100] | d_loss: 1.2788 | g_loss: 0.8454
# Epoch [   42/  100] | d_loss: 1.3943 | g_loss: 0.8518
# Epoch [   43/  100] | d_loss: 1.2556 | g_loss: 0.9898
# Epoch [   43/  100] | d_loss: 1.1812 | g_loss: 1.2569
# Epoch [   43/  100] | d_loss: 1.2797 | g_loss: 1.1020
# Epoch [   44/  100] | d_loss: 1.2879 | g_loss: 0.9625
# Epoch [   44/  100] | d_loss: 1.3726 | g_loss: 1.0106
# Epoch [   44/  100] | d_loss: 1.3732 | g_loss: 0.9916
# Epoch [   45/  100] | d_loss: 1.3930 | g_loss: 1.0511
# Epoch [   45/  100] | d_loss: 1.3682 | g_loss: 0.7861
# Epoch [   45/  100] | d_loss: 1.3718 | g_loss: 1.1415
# Epoch [   46/  100] | d_loss: 1.3357 | g_loss: 0.8941
# Epoch [   46/  100] | d_loss: 1.3535 | g_loss: 0.8929
# Epoch [   46/  100] | d_loss: 1.3337 | g_loss: 1.0375
# Epoch [   47/  100] | d_loss: 1.3945 | g_loss: 0.9897
# Epoch [   47/  100] | d_loss: 1.1819 | g_loss: 0.9877
# Epoch [   47/  100] | d_loss: 1.2941 | g_loss: 1.0005
# Epoch [   48/  100] | d_loss: 1.2863 | g_loss: 1.0706
# Epoch [   48/  100] | d_loss: 1.2576 | g_loss: 0.8802
# Epoch [   48/  100] | d_loss: 1.2768 | g_loss: 0.8067
# Epoch [   49/  100] | d_loss: 1.3557 | g_loss: 0.7656
# Epoch [   49/  100] | d_loss: 1.3000 | g_loss: 0.9259
# Epoch [   49/  100] | d_loss: 1.2655 | g_loss: 0.9873
# Epoch [   50/  100] | d_loss: 1.3118 | g_loss: 0.8931
# Epoch [   50/  100] | d_loss: 1.2669 | g_loss: 1.0287
# Epoch [   50/  100] | d_loss: 1.4461 | g_loss: 1.1272
# Epoch [   51/  100] | d_loss: 1.2648 | g_loss: 0.8038
# Epoch [   51/  100] | d_loss: 1.2855 | g_loss: 0.9886
# Epoch [   51/  100] | d_loss: 1.1118 | g_loss: 1.7946
# Epoch [   52/  100] | d_loss: 1.2979 | g_loss: 0.9049
# Epoch [   52/  100] | d_loss: 1.2431 | g_loss: 1.4696
# Epoch [   52/  100] | d_loss: 1.3199 | g_loss: 0.9146
# Epoch [   53/  100] | d_loss: 1.1200 | g_loss: 1.4664
# Epoch [   53/  100] | d_loss: 1.2657 | g_loss: 0.8749
# Epoch [   53/  100] | d_loss: 1.3191 | g_loss: 0.9261
# Epoch [   54/  100] | d_loss: 1.3068 | g_loss: 0.8307
# Epoch [   54/  100] | d_loss: 1.2298 | g_loss: 1.0005
# Epoch [   54/  100] | d_loss: 1.2618 | g_loss: 1.5276
# Epoch [   55/  100] | d_loss: 1.2218 | g_loss: 1.3107
# Epoch [   55/  100] | d_loss: 1.2601 | g_loss: 1.0110
# Epoch [   55/  100] | d_loss: 1.3150 | g_loss: 0.9608
# Epoch [   56/  100] | d_loss: 1.3616 | g_loss: 0.8285
# Epoch [   56/  100] | d_loss: 1.2487 | g_loss: 1.0502
# Epoch [   56/  100] | d_loss: 1.2500 | g_loss: 0.9707
# Epoch [   57/  100] | d_loss: 1.3195 | g_loss: 1.0546
# Epoch [   57/  100] | d_loss: 1.2675 | g_loss: 1.3625
# Epoch [   57/  100] | d_loss: 1.3165 | g_loss: 1.1191
# Epoch [   58/  100] | d_loss: 1.2716 | g_loss: 1.0833
# Epoch [   58/  100] | d_loss: 1.2682 | g_loss: 1.0090
# Epoch [   58/  100] | d_loss: 1.1773 | g_loss: 1.0577
# Epoch [   59/  100] | d_loss: 1.3142 | g_loss: 1.2059
# Epoch [   59/  100] | d_loss: 1.2889 | g_loss: 0.9764
# Epoch [   59/  100] | d_loss: 1.3059 | g_loss: 1.0805
# Epoch [   60/  100] | d_loss: 1.2168 | g_loss: 1.5541
# Epoch [   60/  100] | d_loss: 1.2200 | g_loss: 1.0486
# Epoch [   60/  100] | d_loss: 1.5318 | g_loss: 1.0489
# Epoch [   61/  100] | d_loss: 1.3112 | g_loss: 0.9070
# Epoch [   61/  100] | d_loss: 1.1727 | g_loss: 1.3533
# Epoch [   61/  100] | d_loss: 1.3986 | g_loss: 0.8512
# Epoch [   62/  100] | d_loss: 1.2951 | g_loss: 1.0228
# Epoch [   62/  100] | d_loss: 1.2130 | g_loss: 0.9688
# Epoch [   62/  100] | d_loss: 1.4242 | g_loss: 1.4703
# Epoch [   63/  100] | d_loss: 1.2924 | g_loss: 0.8507
# Epoch [   63/  100] | d_loss: 1.2421 | g_loss: 1.4081
# Epoch [   63/  100] | d_loss: 1.2716 | g_loss: 0.9771
# Epoch [   64/  100] | d_loss: 1.3278 | g_loss: 1.4606
# Epoch [   64/  100] | d_loss: 1.3280 | g_loss: 0.9502
# Epoch [   64/  100] | d_loss: 1.3393 | g_loss: 0.9777
# Epoch [   65/  100] | d_loss: 1.2029 | g_loss: 0.9540
# Epoch [   65/  100] | d_loss: 1.2603 | g_loss: 0.8679
# Epoch [   65/  100] | d_loss: 1.3544 | g_loss: 1.0633
# Epoch [   66/  100] | d_loss: 1.4285 | g_loss: 1.0469
# Epoch [   66/  100] | d_loss: 1.2363 | g_loss: 0.8463
# Epoch [   66/  100] | d_loss: 1.3826 | g_loss: 0.9245
# Epoch [   67/  100] | d_loss: 1.2785 | g_loss: 0.8546
# Epoch [   67/  100] | d_loss: 1.1205 | g_loss: 1.0593
# Epoch [   67/  100] | d_loss: 1.3577 | g_loss: 1.0922
# Epoch [   68/  100] | d_loss: 1.2606 | g_loss: 1.0844
# Epoch [   68/  100] | d_loss: 1.2951 | g_loss: 1.2154
# Epoch [   68/  100] | d_loss: 1.3603 | g_loss: 1.1143
# Epoch [   69/  100] | d_loss: 1.2540 | g_loss: 1.1579
# Epoch [   69/  100] | d_loss: 1.2875 | g_loss: 1.0747
# Epoch [   69/  100] | d_loss: 1.2611 | g_loss: 1.1461
# Epoch [   70/  100] | d_loss: 1.2360 | g_loss: 0.8858
# Epoch [   70/  100] | d_loss: 1.2466 | g_loss: 1.1815
# Epoch [   70/  100] | d_loss: 1.3264 | g_loss: 0.9893
# Epoch [   71/  100] | d_loss: 1.2964 | g_loss: 1.4716
# Epoch [   71/  100] | d_loss: 1.2722 | g_loss: 1.0908
# Epoch [   71/  100] | d_loss: 1.2938 | g_loss: 0.9901
# Epoch [   72/  100] | d_loss: 1.3763 | g_loss: 0.9090
# Epoch [   72/  100] | d_loss: 1.2370 | g_loss: 1.0313
# Epoch [   72/  100] | d_loss: 1.3087 | g_loss: 0.9554
# Epoch [   73/  100] | d_loss: 1.2598 | g_loss: 1.0630
# Epoch [   73/  100] | d_loss: 1.2484 | g_loss: 1.1710
# Epoch [   73/  100] | d_loss: 1.2855 | g_loss: 1.0331
# Epoch [   74/  100] | d_loss: 1.2943 | g_loss: 1.1714
# Epoch [   74/  100] | d_loss: 1.2839 | g_loss: 0.9176
# Epoch [   74/  100] | d_loss: 1.4247 | g_loss: 0.9905
# Epoch [   75/  100] | d_loss: 1.2728 | g_loss: 1.0917
# Epoch [   75/  100] | d_loss: 1.3122 | g_loss: 0.8945
# Epoch [   75/  100] | d_loss: 1.3279 | g_loss: 1.0449
# Epoch [   76/  100] | d_loss: 1.2418 | g_loss: 1.0129
# Epoch [   76/  100] | d_loss: 1.2830 | g_loss: 1.0090
# Epoch [   76/  100] | d_loss: 1.3397 | g_loss: 0.8901
# Epoch [   77/  100] | d_loss: 1.3277 | g_loss: 0.9401
# Epoch [   77/  100] | d_loss: 1.2542 | g_loss: 0.8708
# Epoch [   77/  100] | d_loss: 1.2764 | g_loss: 0.9009
# Epoch [   78/  100] | d_loss: 1.2960 | g_loss: 1.0675
# Epoch [   78/  100] | d_loss: 1.3443 | g_loss: 1.1518
# Epoch [   78/  100] | d_loss: 1.3056 | g_loss: 0.9658
# Epoch [   79/  100] | d_loss: 1.2566 | g_loss: 1.0118
# Epoch [   79/  100] | d_loss: 1.2020 | g_loss: 1.5460
# Epoch [   79/  100] | d_loss: 1.3124 | g_loss: 0.9600
# Epoch [   80/  100] | d_loss: 1.3332 | g_loss: 0.9692
# Epoch [   80/  100] | d_loss: 1.2516 | g_loss: 1.0593
# Epoch [   80/  100] | d_loss: 1.5096 | g_loss: 1.0194
# Epoch [   81/  100] | d_loss: 1.3452 | g_loss: 1.0195
# Epoch [   81/  100] | d_loss: 1.2846 | g_loss: 0.9641
# Epoch [   81/  100] | d_loss: 1.3814 | g_loss: 0.9416
# Epoch [   82/  100] | d_loss: 1.3707 | g_loss: 1.0672
# Epoch [   82/  100] | d_loss: 1.3054 | g_loss: 0.9782
# Epoch [   82/  100] | d_loss: 1.3148 | g_loss: 0.8738
# Epoch [   83/  100] | d_loss: 1.2512 | g_loss: 1.2073
# Epoch [   83/  100] | d_loss: 1.2985 | g_loss: 0.9675
# Epoch [   83/  100] | d_loss: 1.2564 | g_loss: 0.9478
# Epoch [   84/  100] | d_loss: 1.3111 | g_loss: 1.2358
# Epoch [   84/  100] | d_loss: 1.2953 | g_loss: 0.8650
# Epoch [   84/  100] | d_loss: 1.3750 | g_loss: 0.8592
# Epoch [   85/  100] | d_loss: 1.2071 | g_loss: 1.0386
# Epoch [   85/  100] | d_loss: 1.2630 | g_loss: 1.0287
# Epoch [   85/  100] | d_loss: 1.3011 | g_loss: 1.0934
# Epoch [   86/  100] | d_loss: 1.2097 | g_loss: 1.3008
# Epoch [   86/  100] | d_loss: 1.2283 | g_loss: 0.8004
# Epoch [   86/  100] | d_loss: 1.3633 | g_loss: 1.0827
# Epoch [   87/  100] | d_loss: 1.4281 | g_loss: 1.1680
# Epoch [   87/  100] | d_loss: 1.3331 | g_loss: 1.6283
# Epoch [   87/  100] | d_loss: 1.2177 | g_loss: 0.8798
# Epoch [   88/  100] | d_loss: 1.3598 | g_loss: 0.9361
# Epoch [   88/  100] | d_loss: 1.3104 | g_loss: 1.0588
# Epoch [   88/  100] | d_loss: 1.2613 | g_loss: 1.0356
# Epoch [   89/  100] | d_loss: 1.2722 | g_loss: 1.2739
# Epoch [   89/  100] | d_loss: 1.2824 | g_loss: 0.9674
# Epoch [   89/  100] | d_loss: 1.1925 | g_loss: 1.2167
# Epoch [   90/  100] | d_loss: 1.2272 | g_loss: 1.1862
# Epoch [   90/  100] | d_loss: 1.1791 | g_loss: 1.2417
# Epoch [   90/  100] | d_loss: 1.4226 | g_loss: 1.1619
# Epoch [   91/  100] | d_loss: 1.2623 | g_loss: 1.2550
# Epoch [   91/  100] | d_loss: 1.2616 | g_loss: 1.0457
# Epoch [   91/  100] | d_loss: 1.3328 | g_loss: 0.8505
# Epoch [   92/  100] | d_loss: 1.2869 | g_loss: 1.1203
# Epoch [   92/  100] | d_loss: 1.2725 | g_loss: 0.8606
# Epoch [   92/  100] | d_loss: 1.2152 | g_loss: 1.4296
# Epoch [   93/  100] | d_loss: 1.2469 | g_loss: 1.1116
# Epoch [   93/  100] | d_loss: 1.2493 | g_loss: 0.9079
# Epoch [   93/  100] | d_loss: 1.4259 | g_loss: 0.8037
# Epoch [   94/  100] | d_loss: 1.4844 | g_loss: 1.5977
# Epoch [   94/  100] | d_loss: 1.4275 | g_loss: 0.9440
# Epoch [   94/  100] | d_loss: 1.3485 | g_loss: 0.9304
# Epoch [   95/  100] | d_loss: 1.3357 | g_loss: 1.0633
# Epoch [   95/  100] | d_loss: 1.1385 | g_loss: 1.2237
# Epoch [   95/  100] | d_loss: 1.3823 | g_loss: 1.0101
# Epoch [   96/  100] | d_loss: 1.2965 | g_loss: 1.4230
# Epoch [   96/  100] | d_loss: 1.2833 | g_loss: 0.8903
# Epoch [   96/  100] | d_loss: 1.3047 | g_loss: 0.9531
# Epoch [   97/  100] | d_loss: 1.1805 | g_loss: 1.5922
# Epoch [   97/  100] | d_loss: 1.3425 | g_loss: 0.9564
# Epoch [   97/  100] | d_loss: 1.2474 | g_loss: 1.0624
# Epoch [   98/  100] | d_loss: 1.2249 | g_loss: 0.9211
# Epoch [   98/  100] | d_loss: 1.2096 | g_loss: 1.3931
# Epoch [   98/  100] | d_loss: 1.3680 | g_loss: 0.9783
# Epoch [   99/  100] | d_loss: 1.2650 | g_loss: 0.9943
# Epoch [   99/  100] | d_loss: 1.2330 | g_loss: 0.8675
# Epoch [   99/  100] | d_loss: 1.3430 | g_loss: 0.9039
# Epoch [  100/  100] | d_loss: 1.2246 | g_loss: 1.1086
# Epoch [  100/  100] | d_loss: 1.3134 | g_loss: 0.9992
# Epoch [  100/  100] | d_loss: 1.3780 | g_loss: 0.9714

# %% [markdown]
# ## Training loss
#
# Here we'll plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at the images we saved during training.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 1, 7, 3, 2. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs.

# %%
rows = 10 # split epochs into 10, so 100/10 = every 10 epochs
cols = 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        img = img.detach()
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise like 1s and 9s.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. **We just need to pass in a new latent vector $z$ and we'll get new samples**!

# %%
# randomly generated, new latent vectors
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)

# 0 indicates the first set of samples in the passed in list
# and we only have one batch of samples, here
view_samples(0, [rand_images])
